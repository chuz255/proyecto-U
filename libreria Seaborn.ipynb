# %% [markdown]
# <p Style= "Seaborn" > </p>
#
# <h2> 1.1. Investigacion sobre Seaborn</h2>
# <h3> Seaborn es una biblioteca para crear gráficos estadísticos en Python. Se construye sobre matplotlib e integra de manera cercana con las estructuras de datos de pandas.
#
# Seaborn te ayuda a explorar y entender tus datos. Sus funciones de trazado operan en dataframes y matrices que contienen conjuntos de datos completos y realizan internamente el mapeo semántico necesario y la agregación estadística para producir gráficos informativos. </h3>
#
# <h2>Ventajas de usar Seaborn:</h2>
#
# <ol>
#     <li> Facilidad de uso</li>
#     <li>Integración con pandas </li>
#     <li>Gráficos estadísticos: </li>
#     <li>Compatibilidad con matplotlib </li>
#
# </ol>

# %% [markdown]
# <h2>Ejemplos de gráficas con Seaborn</h2>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h4> Una API de alto nivel para gráficos estadísticos
# No existe una forma universalmente mejor de visualizar datos. Diferentes preguntas encuentran su mejor respuesta en diferentes gráficos. Seaborn facilita el cambio entre diferentes representaciones visuales utilizando una API coherente orientada a conjuntos de datos</h4>
# </h4>La función relplot() tiene ese nombre porque está diseñada para visualizar muchas relaciones estadísticas diferentes.> </h4>

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %% [markdown]
# Estimación estadística
#
# Con frecuencia, nos interesa el valor promedio de una variable en función de otras variables. Muchas funciones de seaborn realizarán automáticamente la estimación estadística necesaria para responder a estas preguntas:

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %% [markdown]
# Representaciones de distribución
#
#
# Los análisis estadísticos requieren conocimiento sobre la distribución de las variables en tu conjunto de datos.
# La función displot() de seaborn admite varios enfoques para visualizar distribuciones.
# Estos incluyen técnicas clásicas como los histogramas y enfoques computacionalmente intensivos como la estimación de densidad de núcleo

# %%
data = {
    "total_bill": [20.75, 10.50, 30.00, 15.80, 12.60, 22.30, 40.50, 18.75],
    "time": ["Lunch", "Lunch", "Dinner", "Lunch", "Dinner", "Dinner", "Dinner", "Lunch"]
}


tips_df = pd.DataFrame(data)

sns.displot(data=tips_df, x="total_bill", col="time", kde=True)

# %% [markdown]
# Visualizar datos categóricos

# %%
data = {
    "deck": ["A", "B", "C", "D", "E", "A", "B", "C", "D", "E"],
    "class": ["First", "Second", "Third", "Third", "First", "Second", "Third", "Second", "Third", "First"],
    "count": [10, 15, 5, 7, 8, 9, 12, 6, 11, 14]
}

deck_data = pd.DataFrame(data)

sns.catplot(data=deck_data, x="deck", kind="count", palette="ch:.25", hue="class")

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load the "tips" dataset from Seaborn

tips = sns.load_dataset("tips")




# Create a density plot of the "total_bill" column from the "tips" dataset

# We use the "hue" parameter to differentiate between "lunch" and "dinner" meal times

# We use the "fill" parameter to fill the area under the curve

# We adjust the "alpha" and "linewidth" parameters to make the plot more visually appealing

sns.kdeplot(data=tips, x="total_bill", hue="time", fill=True, alpha=0.6, linewidth=1.5)




# Add a title and labels to the plot using Matplotlib

plt.title("Density Plot of Total Bill by Meal Time")

plt.xlabel("Total Bill ($)")

plt.ylabel("Density")




# Show the plot

plt.show()

# %% [markdown]
# @article{Waskom2021,
#     doi = {10.21105/joss.03021},
#     url = https://seaborn.pydata.org/tutorial/introduction.html,
#     year = {2021},
#     publisher = {The Open Journal},
#     volume = {6},
#     number = {60},
#     pages = {3021},
#     author = {Michael L. Waskom},
#     title = {seaborn: statistical data visualization},
#     journal = {Journal of Open Source Software}
# }
